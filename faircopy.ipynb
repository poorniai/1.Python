# %%
from basicmultiplefunctions import multipleFunctions

# %%
multipleFunctions.BMI()
# Out:
# Enter the BMI Index: 13
# Underweight
# 'Underweight'

# %%
multipleFunctions.OddEven()
# Out:
# Enter Number 33
# Odd Number
# 'Odd number'
