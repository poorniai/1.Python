# %%
from HelperFunctions import GenericFunctionsClass

# %%
message = GenericFunctionsClass.Subfields()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
GenericFunctionsClass.OddEven()
# Out:
# Enter a number: 53427
# 53427 is Odd number
# '53427 is Odd number'

# %%
GenericFunctionsClass.Eligible()
# Out:
# Your Gender: Male
# Your Age: 20
# NOT ELIGIBLE
# 'NOT ELIGIBLE'

# %%
GenericFunctionsClass.percentage()
# Out:
# Subject1= 98
# Subject2= 97
# Subject3= 99
# Subject4= 98
# Subject5= 96
# Total : 488
# Percentage : 97.59999999999999
# 97.6

# %%
GenericFunctionsClass.triangle()
# Out:
# Height: 13
# Breadth: 17
# Area formula: (Height*Breadth)/2
# Area of Triangle: 110.5
# Height1: 7
# Height2: 3
# Breadth: 9
# Perimeter formula: Height1 + Height2 + Breadth
# Perimeter of Triangle:19
# 19
