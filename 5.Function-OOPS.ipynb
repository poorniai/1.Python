# %%
lists=[23,45,67,34,89]


def AgeCategory():
 for age in lists:
    if(age<18):
        print("Childred")
    elif(age<35):
        print("Adult")
    elif(age<59):
        print("Citizen")
    else:
        print("Senior Citizen")



AgeCategory()
# Out:
# Adult
# Citizen
# Senior Citizen
# Adult
# Senior Citizen

# %%
age=int(input("Enter the age"))
# Out:
# Enter the age 33

# %%
def AgeCategory():
    if(age<18):
        print("Children")
        cate="Children"
    elif(age<35):
        print("Adult")
        cate="Adult"
    elif(age<59):
        print("Citizen")
        cate="Citizen"
    else:
        print("Senior Citizen")
        cate="Senior Citizen"
    return cate

# %%
AgeCategory()
# Out:
# Adult
# 'Children'
