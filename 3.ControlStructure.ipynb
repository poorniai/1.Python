# %%
age=int(input("Enter the Age"))

if(age==18):
    print("Adult")
# Out:
# Enter the Age 32

# %%
age =int(input("Enter Age"))

if(age>=18):
   print("Adult")
else:
   print("Children")
# Out:
# Enter Age 3
# Children

# %%
age =int(input("Enter Age"))

if(age<18):
   print("Children")
elif(age<34):    
   print("Adult")
elif(age<59):
   print("Citizen")
else:
   print("Senior Citizen")
# Out:
# Enter Age 33
# Adult

# %%
lists=[13,23,33,43,53]
for age in lists:
    print("Age List Values:", age)
    if(age<18):
       print("Children")
    elif(age<34):    
       print("Adult")
    elif(age<59):
       print("Citizen")
    else:
       print("Senior Citizen")
# Out:
# Age List Values: 13
# Children
# Age List Values: 23
# Adult
# Age List Values: 33
# Adult
# Age List Values: 43
# Citizen
# Age List Values: 53
# Citizen

# %%
num1=int(input("Enter Number"))
if((num1%2)==0):
    print("Even Number",num1)
else:
    print("odd",num1)
# Out:
# Enter Number 30
# Even Number 30

# %%
num1=int(input("Enter Number"))
if((num1%2)==1):
    print("Odd Number",num1)
elif((num1%2)==0):
    print("Event",num1)
# Out:
# Enter Number 33
# Odd Number 33

# %%
for temp in range(0,10):
    print("Range",temp)
# Out:
# Range 0
# Range 1
# Range 2
# Range 3
# Range 4
# Range 5
# Range 6
# Range 7
# Range 8
# Range 9

# %%
for temp in range(3,10):
    print("Range",temp)
# Out:
# Range 3
# Range 4
# Range 5
# Range 6
# Range 7
# Range 8
# Range 9

# %%
for temp in range(3,10,3):
    print("Range",temp)
# Out:
# Range 3
# Range 6
# Range 9
