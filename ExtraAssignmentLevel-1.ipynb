# %%
print("Hope AI")
# Out:
# Hope AI

# %%
instituteName=input("Enter your Institue name? :")
# Out:
# Enter your Institue name? : Hope AI

# %%
studentName=input("Enter your name:")
age=int(input("Enter your age:"))
schoolname=input("Enter your School name:")
degree=input("Enter your drgree:")
# Out:
# Enter your name: Raj
# Enter your age: 15
# Enter your School name: Guru School
# Enter your drgree: B.E CSE

# %%
a=43
b=34
print("a= ",a)
print("b= ",b)
print("Add= ",(a+b));
# Out:
# a=  43
# b=  34
# Add=  77

# %%
a=43
b=34
print("a= ",a)
print("b= ",b)
print("Sub= ",(a-b));
# Out:
# a=  43
# b=  34
# Sub=  9

# %%
a=63
b=97
print("a= ",a)
print("b= ",b)
print("Multiplication= ",(a*b));
# Out:
# a=  63
# b=  97
# Multiplication=  6111

# %%
a=76
b=31
print("a= ",a)
print("b= ",b)
print("Division= ",(a/b));
# Out:
# a=  76
# b=  31
# Division=  2.4516129032258065

# %%
a=76
b=31
print("a= ",a)
print("b= ",b)
print("Floor Div= ",(a//b));
# Out:
# a=  76
# b=  31
# Floor Div=  2

# %%
a=76
b=31
print("a= ",a)
print("b= ",b)
print("Modulo= ",(a%b));
# Out:
# a=  76
# b=  31
# Modulo=  14
