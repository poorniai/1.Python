# %%
print("Welcome to Assignment-1")
# Out:
# Welcome to Assignment-1

# %%
print('Welcome to Assignment-1')
# Out:
# Welcome to Assignment-1

# %%
Num1=10
Num2=30
print("Num1= ",Num1)
print("Num2= ",Num2)
print("Add= ", Num1+Num2)
# Out:
# Num1=  10
# Num2=  30
# Add=  40

# %%
Num1=10
Num2=30
print("Num1= ",Num1)
print("Num2= ",Num2)
Add=Num1+Num2
print("Add= ",Add)
# Out:
# Num1=  10
# Num2=  30
# Add=  40

# %%
bmiIndex=float(input("Enter the BMI Index:"))
if(bmiIndex<=18.4):
    print("Under Weight:", bmiIndex)
elif(bmiIndex<=24.9):    
    print("Healthy Weight:", bmiIndex)
elif(bmiIndex<=29.9):    
    print("Over Weight:", bmiIndex)
elif(bmiIndex<=34.9):    
    print("Class1 Obseity:", bmiIndex)
elif(bmiIndex<=39.9):    
    print("Class2 Obseity:", bmiIndex)
else:   
    print("Class3 Obseity:", bmiIndex)
# Out:
# Enter the BMI Index: 39.9
# Class2 Obseity: 39.9
