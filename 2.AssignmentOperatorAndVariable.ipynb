# %%
num1=10
num2=20
add=num1+num2
print("Result",add)
# Out:
# Result 30

# %%
print("Addition of Two Numbers")
num1=10
num2=20
print("The Number1:",num1)
print("The Number2:",num2)
add=num1+num2
print("The Answer",add)
# Out:
# Addition of Two Numbers
# The Number1: 10
# The Number2: 20
# The Answer 30

# %%
num1=input("Enter the Num1:")
num2=input("Enter the Num2:")
add = num1+num2
print("Multiplication of Num1 and Num2",add)
# Out:
# Enter the Num1: 10
# Enter the Num2: 20
# Multiplication of Num1 and Num2 1020

# %%
name='Meenakshi'
print(name)
# Out:
# Meenakshi
